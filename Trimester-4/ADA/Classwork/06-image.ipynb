# %%
from skimage import io, color
from skimage.measure import shannon_entropy
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img_rgb = cv2.imread('hist.jpg')

# %%
hist = cv2.calcHist([img_rgb], [0], None, [256], [0, 256])

plt.figure()
plt.title('Grayscale Histogram')
plt.ylabel('Number of Pixels')
plt.xlabel('Intensity Value')
plt.plot(hist)
plt.show()

# %%
plt.imshow(img_rgb)

# %%
img = cv2.imread('color.jpg')
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)

# %%
colors = ['red', 'green', 'blue']

plt.figure()
for i, color in enumerate(colors):
    hist = cv2.calcHist([img_rgb], [i], None, [256], [0, 256])
    plt.plot(hist, color=color)
    plt.xlim([0, 256])
plt.title('Color Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Number of Pixels')
plt.legend(colors)
plt.show()

# %%
a = ['bd.jpg', 'gd.jpg', 'yd.jpg']

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 5))

for idx, i in enumerate(a):
    img = cv2.imread(i)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    colors = ['red', 'green', 'blue']

    for j, color in enumerate(colors):
        hist = cv2.calcHist([img_rgb], [j], None, [256], [0, 256])
        axes[1][idx].plot(hist, color=color)
        axes[1][idx].set_xlim([0, 256])

    axes[0][idx].imshow(img_rgb)
    
    axes[1][idx].set_title(f'Color Histogram of {i}')
    axes[1][idx].set_xlabel('Pixel Intensity')
    axes[1][idx].set_ylabel('Number of Pixels')
    axes[1][idx].legend(colors)

plt.tight_layout()
plt.show()

# %%
img = cv2.imread('hist.jpg', cv2.IMREAD_GRAYSCALE)

eq_img = cv2.equalizeHist(img)

# %%
def display_images_and_histograms(original, equalized):
    fig, axes = plt.subplots(2, 2, figsize=(12, 6))
    
    axes[0, 0].imshow(original, cmap='gray')
    axes[0, 0].set_title('Original Image')
    axes[0, 0].axis('off')
    
    axes[0, 1].imshow(equalized, cmap='gray')
    axes[0, 1].set_title('Equalized Image')
    axes[0, 1].axis('off')

    axes[1, 0].hist(original.ravel(), bins=256, range=[0,256])
    axes[1, 0].set_title('Histogram of Original Image')

    axes[1, 1].hist(equalized.ravel(), bins=256, range=[0,256])
    axes[1, 1].set_title('Histogram of Equalized Image')

    plt.tight_layout()
    plt.show()

# %%
display_images_and_histograms(img, eq_img)

# %%
def dsp(path):
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    eq_img = cv2.equalizeHist(image)

    display_images_and_histograms(image, eq_img)

# %%
dsp('blr.jpg')

# %%
dsp('bright.jpg')

# %%
dsp('white.webp')
